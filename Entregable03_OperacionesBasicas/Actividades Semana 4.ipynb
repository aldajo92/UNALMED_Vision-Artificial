# %% [markdown]
# # Actividades Semana 4

# %% [markdown]
# A continuación se presentan los ejercicios que el estudiante debe desarrollar, para afianzar los conceptos vistos acerca de transformaciones básicas de la imagen.

# %% [markdown]
# ## Actividad 1.

# %% [markdown]
# Lea la imagen "power_rangers.jpg" que se encuentra en la carpeta "res", y mediante las operaciones báscicas, obtenga un aproximado de la salida esperada.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Se realiza la lectura de la imagen
img = cv2.cvtColor(cv2.imread('res/power_rangers.jpg'), cv2.COLOR_BGR2RGB)
#img_op es una matriz de ceros del mismo tamaño de la imagen original, corresponde a una copia para editar.
#el tipo de dato debe ser uint8 para estar entre 0 y 255
img_op = np.zeros(img.shape, np.uint8)

####SU CODIGO AQUÍ#####
q = 50 ;  w = 30; e = 30
#####TERMINA SU CODIGO#####

#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_op[:,:,0] = cv2.add(img[:,:,0], q)
img_op[:,:,1] = cv2.subtract(img[:,:,1], w)
img_op[:,:,2] = cv2.subtract(img[:,:,2], e)

#Se realiza el arreglo de 2x2 para mostrar imagen e imagen modificada vs histogramas
fig, arreglo_plots = plt.subplots(2,2, figsize=(15, 15))
colors = ('r','g','b')

#Se le dan títulos a los cuadros, se imprimen las imágenes y sus histogramas
arreglo_plots[0,0].set_title('Imagen original')
arreglo_plots[0,0].imshow(img, cmap="gray")
arreglo_plots[0,1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img[:,:,i].ravel()
    arreglo_plots[0,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),density=True, color=colors[i])

arreglo_plots[1,0].set_title('Imagen modificada')
arreglo_plots[1,0].imshow(img_op, cmap="gray")
arreglo_plots[1,1].set_title('Histograma modificado')
for i,col in enumerate(colors):
    img_array_i = img_op[:,:,i].ravel()
    arreglo_plots[1,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),density=True, color=colors[i])

# %% [markdown]
# ### Salida esperada:
#
# <img src = "res/solucion_1.png">

# %% [markdown]
# ## Actividad 2.

# %% [markdown]
# Lea la imagen "super_poderosas.jpg" que se encuentra en la carpeta "res", y mediante las operaciones báscicas, obtenga un aproximado de la salida esperada.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Se realiza la lectura de la imagen
img = cv2.cvtColor(cv2.imread('res/super_poderosas.jpg'), cv2.COLOR_BGR2RGB)
#img_add es una matriz de ceros del mismo tamaño de la imagen original, corresponde a una copia para editar.
#el tipo de dato debe ser uint8 para estar entre 0 y 255
img_op = np.zeros(img.shape, np.uint8)

####SU CODIGO AQUÍ#####
q = -255 ;  w = 0; e = 0
#####TERMINA SU CODIGO#####

#Se sustituyen los valores de cada canal de la copia por los valores modificados de la imagen original
img_op[:,:,0] = cv2.add(img[:,:,0], q)
img_op[:,:,1] = cv2.add(img[:,:,1], w)
img_op[:,:,2] = cv2.add(img[:,:,2], e)

#Se realiza el arreglo de 2x2 para mostrar imagen e imagen modificada vs histogramas
fig, arreglo_plots = plt.subplots(2,2, figsize=(15, 15))
colors = ('r','g','b')

#Se le dan títulos a los cuadros, se imprimen las imágenes y sus histogramas
arreglo_plots[0,0].set_title('Imagen original')
arreglo_plots[0,0].imshow(img, cmap="gray")
arreglo_plots[0,1].set_title('Histograma original')
for i,col in enumerate(colors):
    img_array_i = img[:,:,i].ravel()
    arreglo_plots[0,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),density=True, color=colors[i])

arreglo_plots[1,0].set_title('Imagen modificada')
arreglo_plots[1,0].imshow(img_op, cmap="gray")
arreglo_plots[1,1].set_title('Histograma modificado')
for i,col in enumerate(colors):
    img_array_i = img_op[:,:,i].ravel()
    arreglo_plots[1,1].hist(img_array_i,histtype='step', bins=255, 
                            range=(0.0, 255.0),density=True, color=colors[i])

# %% [markdown]
# ### Salida esperada:
#
# <img src = "res/solucion_2.png">

# %% [markdown]
# ## Actividad 3.

# %% [markdown]
# A continuación se presenta el siguiente problema al aplicar el operador AND sobre la imagen "pintura.jpg"
#
# <img src="res/error.png"/>
#
# Lea la imagen "pintura.jpg" y la máscara "mascara.png" que se encuentran en la carpeta "res".
# <br>Escriba, en la casilla inferior, un código que arroje este resultado equivocado.</br>

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

###Escriba aquí el código###
#Se lee la imagen
img = cv2.cvtColor(cv2.imread('res/pintura.jpg'), cv2.COLOR_BGR2RGB)
####SU CODIGO AQUÍ#####
mascara = cv2.cvtColor(cv2.imread('res/mascara.png'), cv2.COLOR_BGR2RGB)
#####TERMINA SU CODIGO#####

#Ajustar el tamaño de la máscara al de la img
mascara = cv2.resize(mascara, (img.shape[1], img.shape[0]))
#Aplicar la operación AND sobre la imagen de entrada y la máscara
####SU CODIGO AQUÍ#####
out = img * mascara
out = out/255
#####TERMINA SU CODIGO#####
#Generar un subplot 1x3 para mostrar la imagen de entrada, la máscara y la operación AND
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(15, 7))
ax1.set_title('Imagen de entrada')
ax2.set_title('Máscara')
ax3.set_title('Operación lógica')
ax1.imshow(img, cmap='gray')
ax2.imshow(mascara, cmap='gray')
ax3.imshow(out, cmap='gray')

# %% [markdown]
# Ahora, escriba el código que arroja el resultado correcto sobre la imagen de entrada.

# %%
###Escriba aquí el código###

#Se lee la imagen
img = cv2.cvtColor(cv2.imread('res/pintura.jpg'), cv2.COLOR_BGR2RGB)
####SU CODIGO AQUÍ#####
mascara = cv2.imread('res/mascara.png')/255
#####TERMINA SU CODIGO#####
#Ajustar el tamaño de la máscara al de la img
mascara = cv2.resize(mascara, (img.shape[1], img.shape[0]))

#Aplicar la operación AND sobre la imagen de entrada y la máscara
####SU CODIGO AQUÍ#####
out = img * mascara
out = out/255
#####TERMINA SU CODIGO#####
#Generar un subplot 1x3 para mostrar la imagen de entrada, la máscara y la operación AND
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(15, 7))
ax1.set_title('Imagen de entrada')
ax2.set_title('Máscara')
ax3.set_title('Operación lógica')
ax1.imshow(img, cmap='gray')
ax2.imshow(mascara, cmap='gray')
ax3.imshow(out, cmap='gray')

# %% [markdown]
# #### Sugerencia, utilice como base el ejemplo de clase con la imagen "pibe.jpg"
